# %% [markdown]
# <a href="https://colab.research.google.com/github/ernestoffor3-art/ai-annotation-quality-audit/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Analysis Demo
#
# This notebook demonstrates basic data analysis:
# - Loading data
# - Summary statistics
# - Visualization

# %% [markdown]
# # Student Performance Analysis
#
# ## Objective
# Analyze student scores across subjects to identify performance patterns and insights.

# %% [markdown]
# ## Key Insights
#
# - Students with high Math scores tend to perform well overall
# - There is a noticeable gap between top and low performers
# - Science scores are generally highest across students

# %%
df.set_index("Name")[["Math","English","Science"]].plot(kind='bar')
plt.title("Scores by Student and Subject")
plt.savefig("visuals/performance_by_category.png")
plt.show()

# %%
df["Average"].plot(kind='hist', bins=5)
plt.title("Distribution of Average Scores")
plt.savefig("visuals/score_distribution.png")
plt.show()

# %%
df["Average"] = df[["Math", "English", "Science"]].mean(axis=1)
df

# %%
df.info()
df.describe()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("dataset.csv")
df.head()
